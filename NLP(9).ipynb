# %%
from collections import Counter

text = "I love NLP and I love Python"

words = text.lower().split()

word_counts = Counter(words)

total_words = len(words)

vocabulary_size = len(word_counts)

print("Word Counts:")
print(word_counts)

print("\nLaplace Smoothed Probabilities:")

for word in word_counts:
    probability = (word_counts[word] + 1) / (total_words + vocabulary_size)
    print(word, ":", round(probability, 4))
unseen_word_probability = 1 / (total_words + vocabulary_size)

print("\nProbability of unseen word 'data':",
      round(unseen_word_probability, 4))

#Laplace smoothing is a technique used in statistics and machine learning to
#fix the "zero-probability problem" by adding a small constant to observation counts
# Out:
# Word Counts:
# Counter({'i': 2, 'love': 2, 'nlp': 1, 'and': 1, 'python': 1})
#
# Laplace Smoothed Probabilities:
# i : 0.25
# love : 0.25
# nlp : 0.1667
# and : 0.1667
# python : 0.1667
#
# Probability of unseen word 'data': 0.0833
